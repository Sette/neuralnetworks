# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import csv
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer,CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/sette/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
mlp = MLPClassifier(alpha=1)
stop = set(stopwords.words('english'))
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')

reader = pd.read_csv('spam.csv', encoding='Latin-1', delimiter=",")
X_train_test = reader.v2

train, test = train_test_split(reader, test_size=0.3)

X_train = train.v2
Y_train = train.v1

X_test = test.v2
Y_test = test.v1

X_train_list = []
for row in X_train:
	#print("Progress:", (index+1), "/", self.totalsents)
    row = re.sub("[^a-zA-Z]", " ", row.lower())

	#row = [self.wordnet_lemmatizer.lemmatize(self.porter_stemmer.stem(w)) \
	#for w in self.tokenizer.tokenize(row) if w not in self.stopwords \
    row = [w for w in tokenizer.tokenize(row) if w not in stop if len(w) > 3]
	#row = ' '.join(row)
    print(row)
    X_train_list.append(row)


tfidf_transformer = TfidfVectorizer()

clf = mlp.fit(tfidf_transformer.fit_transform(X_train), Y_train)
predict = clf.predict(tfidf_transformer.transform(X_test))

print(accuracy_score(Y_test, predict))

sections = ['ham',"spam"]
cm = confusion_matrix(Y_test, predict, labels = sections)
print(cm)
# Out:
# ['dude', 'parked', 'sunroof', 'popped']
# ['angry', 'happen', 'dear']
# ['tick', 'tick', 'tick', 'babe']
# ['wamma', 'laid', 'want', 'real', 'doggin', 'locations', 'sent', 'direct', 'mobile', 'join', 'largest', 'dogging', 'network', 'dogs']
# []
# ['purity', 'friendship', 'smiling', 'reading', 'forwarded', 'message', 'smiling', 'seeing', 'name', 'evng']
# ['thgt', 'clash', 'really', 'mind', 'seen', 'lost', 'weight']
# ['people', 'game', 'mall', 'iouri', 'kaila']
# ['wait', 'party', 'together']
# ['come', 'online', 'today', 'night']
# ['generally', 'uncountable', 'noun', 'dictionary', 'pieces', 'research']
# ['daaaaa', 'home', 'babe', 'still']
# ['bought', 'ringtone', 'getting', 'texts', 'costing', 'pound', 'offering', 'tones']
# []
# ['angry', 'come', 'home', 'tonight']
# ['problem', 'talk', 'later']
# ['made', 'payments', 'dont', 'much', 'sorry', 'would', 'want', 'fedex']
# ['looking', 'good']
# ['gain', 'rights', 'wife', 'dont', 'demand', 'trying', 'husband', 'lets']
# ['alright', 'gotta', 'change', 'order', 'half']
# ['call', 'tomorrow', 'call', 'look', 'irene', 'cres', 'tech', 'park', 'days']
# ['place', 'town', 'meet', 'exciting', 'adult', 'singles', 'chat']
# ['private', 'account', 'statement', 'shows', 'redeemed', 'points', 'call', 'identifier', 'code', 'expires']
# ['taste', 'fish', 'curry']
# ['changes', 'report', 'already', 'made', 'changes', 'previous', 'report']
# ['didnt', 'complete', 'gist']
# ['important', 'customer', 'service', 'announcement', 'premier', 'call', 'freephone']
# ['song', 'creative', 'neva', 'test', 'quality', 'said', 'check', 'review', 'online']
# ['answerin', 'phone', 'actually', 'pretty', 'reasonable', 'hour', 'sleepy']
# ['happy', 'valentines', 'know', 'early', 'hundreds', 'handsomes', 'beauties', 'wish', 'thought', 'finish', 'aunties', 'uncles']
# ['going']
# ['remember', 'last', 'nite']
# ['living', 'simple', 'loving', 'also', 'simple', 'laughing', 'simple', 'winning', 'tooo', 'simple', 'simple', 'difficult']
# ['course', 'make', 'stink']
# ['hurry', 'home', 'butt', 'hang', 'last', 'caller', 'food', 'done', 'starving', 'cooked']
# ['electricity', 'went']
# ['tiime', 'break', 'tears']
# ['congrats', 'mobile', 'videophones', 'call', 'videochat', 'mates', 'play', 'java', 'games', 'dload', 'polyph', 'music', 'noline', 'rentl']
# ['photoshop', 'makes', 'computer', 'shut']
# ['booked', 'already', 'lessons', 'going', 'keep', 'night', 'free', 'need', 'meet', 'confirm', 'lodging']
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'game', 'mobile', 'right', 'text', 'spider', 'game', 'send', 'free', 'ball', 'wallpaper']
# ['walked', 'moms', 'right', 'stagwood', 'pass', 'right', 'winterstone', 'left', 'victors', 'hill', 'address']
# ['lucky', 'save', 'money']
# ['finally', 'missed', 'cinema', 'trip', 'last', 'week']
# ['opinion', 'jada', 'kusruthi', 'lovable', 'silent', 'character', 'matured', 'stylish', 'simple', 'reply']
# ['pple', 'nights', 'excellent', 'location', 'breakfast', 'hamper']
# ['allo', 'braved', 'buses', 'taken', 'trains', 'triumphed', 'mean', 'jolly', 'good', 'rest', 'week']
# ['exactly', 'anyways', 'jide', 'study', 'visiting']
# ['know', 'result']
# ['going', 'bath', 'next']
# ['later', 'wearing', 'shorts']
# ['science', 'tells', 'chocolate', 'melt', 'sunlight', 'please', 'walk', 'sunlight', 'bcoz', 'want', 'loss', 'sweet', 'friend']
# ['popping', 'ibuprofens', 'help']
# ['sure', 'time', 'finish', 'tomorrow', 'wanna', 'spend', 'evening', 'would', 'vewy', 'vewy', 'lubly', 'love']
# ['would', 'fuckin', 'believe', 'didnt', 'know', 'thurs', 'booked', 'cancelled', 'needs', 'sacked']
# ['like', 'torture', 'watching', 'england']
# ['moby', 'quiz', 'high', 'street', 'prize', 'know', 'duchess', 'cornwall', 'first', 'name', 'unsub', 'stop', 'arrow']
# ['guessin', 'gonna']
# ['jokin', 'depends', 'phone', 'father']
# ['okie']
# ['went', 'ganesh', 'dress', 'shop']
# ['anything']
# ['thanks', 'ringtone', 'order', 'number', 'mobile', 'charged', 'tone', 'arrive', 'please', 'call', 'customer', 'services']
# ['worries', 'hope', 'photo', 'shoot', 'went', 'well', 'spiffing', 'workage']
# ['good', 'afternoon', 'love', 'goes', 'hope', 'maybe', 'leads', 'think', 'boytoy', 'send', 'passionate', 'kiss', 'across']
# ['sweetheart', 'hope', 'kind', 'loads', 'reasons', 'smile', 'biola']
# ['specialisation', 'work', 'slave', 'labor', 'look', 'month', 'shakara', 'beggar']
# ['cant', 'pick', 'phone', 'right', 'send', 'message']
# ['arun', 'transfr']
# ['slept', 'time']
# ['someone', 'know', 'asked', 'dating', 'service', 'contact', 'cant', 'guess', 'call', 'revealed']
# ['nothing']
# ['place']
# ['someonone', 'know', 'trying', 'contact', 'dating', 'service', 'find', 'could', 'call', 'mobile', 'landline']
# ['take', 'care', 'umma']
# ['relaxing', 'time', 'ever', 'every', 'party', 'good', 'night', 'home', 'tomorrow']
# ['waiting', 'machan', 'call', 'free']
# ['think', 'match']
# ['sorry', 'dont']
# ['please', 'charge', 'mobile', 'morning']
# ['last', 'practice']
# ['september']
# ['aiyah', 'wait', 'entertain']
# ['bishan', 'lavender']
# ['howz', 'pain', 'come', 'today', 'said', 'ystrday', 'medicine']
# ['piggy', 'awake', 'still', 'sleeping', 'going', 'lunch']
# ['watching', 'movie', 'netflix']
# ['fuuuuck', 'need', 'stop', 'sleepin']
# ['always', 'available', 'work', 'place']
# ['honeybee', 'said', 'sweetest', 'world', 'laughed', 'said', 'wait', 'havnt', 'person', 'reading', 'moral', 'even', 'crack', 'jokes']
# ['good', 'thinking']
# ['important', 'message', 'final', 'contact', 'attempt', 'important', 'messages', 'waiting', 'customer', 'claims', 'dept', 'expires', 'call']
# ['free', 'message', 'thanks', 'using', 'auction', 'subscription', 'service', 'msgrcvd', 'skip', 'auction', 'unsubscribe', 'stop', 'customercare']
# ['make', 'note', 'exposed', 'also', 'find', 'school', 'anyone', 'else', 'vomiting', 'house', 'know', 'later']
# ['bring', 'home', 'wendy']
# ['dice', 'class', 'thru', 'thanks', 'though', 'idea', 'time', 'come', 'tomorrow']
# ['tessy', 'favor', 'convey', 'birthday', 'wishes', 'nimya', 'forget', 'today', 'birthday', 'shijas']
# ['xmas', 'prize', 'draws', 'trying', 'contact', 'todays', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'land', 'line', 'valid']
# ['whatever', 'want', 'know', 'rules', 'talk', 'earlier', 'week', 'start', 'happening', 'showing', 'responsibility', 'every', 'week', 'bend', 'rule', 'whatever', 'tired', 'thia', 'argument', 'every', 'week', 'movie', 'doesnt', 'inlude', 'previews', 'still', 'getting']
# ['advance', 'happy', 'pongal']
# ['texted', 'finished', 'long', 'time', 'showered', 'ything']
# ['also', 'fine', 'complete', 'course']
# ['like', 'hotel', 'dusk', 'game', 'think', 'solve', 'puzzles', 'area', 'thing']
# ['nice', 'nice', 'working']
# ['want', 'meet', 'morro']
# ['says', 'year', 'money', 'last', 'still', 'waiting', 'check']
# ['lecture', 'cheery']
# ['room', 'number', 'wanna', 'make', 'sure', 'knocking', 'right', 'door']
# ['tired', 'special']
# ['horrible', 'macs', 'forgot', 'already', 'rite', 'take', 'long', 'reply', 'toot', 'prepared', 'shall']
# ['picked', 'receipt', 'something', 'earlier']
# ['great', 'getting', 'worried', 'know', 'wonderful', 'caring', 'person', 'like', 'best', 'life', 'know', 'wonderful', 'love']
# ['always', 'brainy']
# ['someone', 'conacted', 'dating', 'service', 'entered', 'phone', 'fancy', 'find', 'call', 'landline', 'pobox']
# ['sorry', 'call', 'later', 'meeting']
# ['winner', 'foley', 'ipod', 'exciting', 'prizes', 'soon', 'keep', 'mobile', 'visit']
# ['reach', 'home', 'call']
# ['urgent', 'trying', 'contact', 'todays', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'land', 'line', 'claim', 'valid']
# ['complimentary', 'star', 'ibiza', 'holiday', 'cash', 'needs', 'urgent', 'collection', 'landline', 'lose']
# ['nothing', 'bored', 'home', 'early', 'sleep', 'today']
# ['many', 'responsibilities']
# ['chennai', 'velachery']
# ['none', 'happening', 'though']
# ['started', 'send', 'requests', 'make', 'pain', 'came', 'back', 'back', 'double', 'coins', 'factory', 'gotta', 'cash', 'nitros']
# ['stop', 'story', 'told', 'returned', 'saying', 'order']
# ['cooking', 'dinner']
# ['sorry', 'thangam', 'sorry', 'held', 'prasad']
# ['want', 'cock', 'hubby', 'away', 'need', 'real', 'satisfy', 'wife', 'strings', 'action', 'stop', 'otbox']
# ['mate', 'spoke', 'people', 'deliver', 'month', 'deliver', 'sept', 'talk', 'later']
# ['class', 'reunion']
# ['going', 'wear', 'sport', 'shoes', 'anyway', 'going', 'late']
# ['pity', 'mood', 'suggestions']
# ['said', 'went', 'back', 'sleep', 'anything']
# ['congratulations', 'week', 'competition', 'draw', 'prize', 'claim', 'call', 'stop']
# ['said', 'right', 'giggle', 'would', 'possibly', 'first', 'person', 'think', 'much', 'could']
# ['dunno', 'driving']
# ['also', 'remember', 'beads', 'come', 'ever']
# ['thanks']
# ['gonna', 'uterus']
# ['sure', 'driving', 'reach', 'destination', 'soon']
# ['boat', 'still', 'moms', 'check', 'half', 'naked']
# ['know', 'dramatic', 'schools', 'already', 'closed', 'tomorrow', 'apparently', 'drive', 'inch', 'snow', 'supposed']
# ['gimme', 'minutes']
# ['arngd', 'marriage', 'walkin', 'unfortuntly', 'snake', 'bites', 'love', 'marriage', 'dancing', 'frnt', 'snake', 'sayin', 'bite', 'bite']
# ['office', 'around', 'going', 'hospital']
# ['quiteamuzing', 'scool', 'babe']
# ['hello', 'damn', 'christmas', 'thing', 'think', 'decided', 'keep', 'doesnt', 'work']
# ['sorry', 'vikky', 'watching', 'olave', 'mandara', 'movie', 'kano', 'trishul', 'theatre', 'frnds']
# ['coming', 'friday', 'leave', 'pongal', 'news', 'work', 'place']
# ['xmas', 'years', 'tickets', 'sale', 'club', 'till', 'thurs', 'night', 'week', 'selling', 'fast']
# ['come', 'back', 'tampa', 'ffffuuuuuuu']
# ['please', 'come', 'imin', 'town', 'dontmatter', 'urgoin', 'outl']
# ['free', 'give', 'otherwise', 'nalla', 'entey', 'nattil', 'kittum']
# ['skip', 'right', 'outside', 'front', 'house', 'house', 'pull']
# ['training']
# ['need', 'campus', 'could', 'pick', 'hour']
# ['ripped', 'mobile', 'content', 'clubmoby', 'call', 'poly', 'true', 'ringtones', 'games', 'downloads']
# ['made', 'taunton', 'planned', 'hope', 'still', 'okday', 'good']
# ['happy', 'year']
# ['mathews', 'tait', 'edwards', 'anderson']
# ['carry', 'disturbing']
# ['well', 'without', 'could', 'sale', 'together']
# ['december', 'mobile', 'mths', 'entitled', 'update', 'latest', 'colour', 'camera', 'mobile', 'free', 'call', 'mobile', 'update', 'free']
# ['text', 'meet', 'someone', 'sexy', 'today', 'find', 'date', 'even', 'flirt', 'join', 'reply', 'name', 'recd', 'thirtyeight', 'pence']
# []
# ['hahaha', 'brain', 'dear']
# ['wanna', 'harri']
# ['fact', 'although', 'would', 'think', 'armand', 'would', 'eventually', 'build', 'tolerance', 'shit', 'considering', 'much', 'smokes', 'gets', 'fucked', 'like', 'hits']
# ['elaine', 'today', 'meeting', 'still']
# ['people', 'dogging', 'area', 'call', 'join', 'like', 'minded', 'guys', 'arrange', 'evening', 'minapn']
# ['much', 'payed', 'suganya']
# ['prolly', 'yeah']
# ['trip', 'postponed', 'still', 'stocked']
# ['dont', 'know', 'getting', 'messages']
# ['shopping', 'stuff', 'watch', 'infernal', 'affairs', 'come']
# ['awww', 'sweet', 'think', 'something', 'nice', 'time', 'tonight', 'probably', 'later', 'lonely']
# ['wanted', 'wait', 'finish', 'lect', 'lect', 'finishes', 'hour', 'anyway']
# ['something', 'dear', 'read', 'something', 'exams']
# ['thanx', 'birthday', 'already']
# ['booked', 'lessons', 'liao']
# ['thanks', 'picking', 'trash']
# ['right', 'diet', 'everyday', 'cheat', 'anyway', 'meant', 'fatty']
# ['dropped', 'back']
# ['nigh', 'cant']
# ['must', 'walk', 'everywhere', 'cannot', 'take', 'tram', 'cousin', 'said', 'walk', 'market', 'hotel']
# ['gave', 'photo', 'registered', 'driving', 'wanna', 'meet']
# ['yalru', 'lyfu', 'astne', 'chikku', 'innu', 'mundhe', 'halla', 'bilo', 'marriage', 'program', 'edhae', 'chikku', 'vargu', 'lyfu', 'meow', 'meow']
# ['askd', 'question', 'hours', 'answer']
# ['aslamalaikkum', 'insha', 'allah', 'tohar', 'beeen', 'muht', 'albi', 'mufti', 'mahfuuz', 'meaning']
# ['xclusive', 'clubsaisai', 'morow', 'soiree', 'speciale', 'zouk', 'nichols', 'paris', 'free', 'roses', 'ladies', 'info']
# ['sent', 'maga', 'money', 'yesterday']
# ['anyway', 'holla', 'whenever', 'around', 'need', 'excuse', 'creep', 'people', 'sarasota']
# ['sitting', 'nothing', 'busy', 'work']
# ['customer', 'place', 'call']
# ['buying']
# ['find', 'time', 'need', 'sort', 'stuff']
# ['natalie', 'inviting', 'friend', 'reply', 'natalie', 'stop', 'send', 'stop', 'frnd']
# ['whens', 'radio', 'show']
# ['leave']
# ['bits', 'pieces', 'sighs']
# ['pool', 'money', 'together', 'bunch', 'lotto', 'tickets', 'deal']
# ['urgent', 'awarded', 'complimentary', 'trip', 'eurodisinc', 'trav', 'entry', 'claim', 'morefrmmob', 'shracomorsglsuplt']
# ['nokia', 'plus', 'free', 'digital', 'camera', 'free', 'auction', 'take', 'part', 'send', 'nokia', 'pobox']
# ['common', 'hearin', 'something', 'different', 'smile', 'today', 'evng']
# ['mobile', 'months', 'entitled', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'call', 'mobile', 'update', 'free']
# ['cmon', 'babe', 'make', 'horny', 'turn', 'fantasy', 'babe', 'sticky', 'need', 'replies', 'cost', 'cancel', 'send', 'stop']
# ['carlos', 'took', 'leave', 'minute']
# ['went', 'fast', 'asleep', 'dear', 'take', 'care']
# ['leave', 'house']
# ['business']
# ['hope', 'settled', 'school', 'year', 'wishin']
# ['haha', 'awesome', 'minute']
# ['raji', 'favour', 'convey', 'birthday', 'wishes', 'nimya', 'today', 'birthday']
# ['chikku', 'favourite', 'song']
# ['lost', 'help']
# ['sorry', 'call', 'later']
# []
# ['phony', 'award', 'todays', 'voda', 'numbers', 'ending', 'xxxx', 'selected', 'receive', 'award', 'match', 'please', 'call', 'quoting', 'claim', 'code', 'standard', 'rates']
# ['frnd', 'necesity', 'life', 'imagine', 'urself', 'witout', 'frnd', 'feel', 'colleg', 'cell', 'functions', 'thnk', 'events', 'espe', 'cared', 'missed', 'irritated', 'dear', 'loving', 'frnds', 'wthout', 'cant', 'live', 'takecare', 'goodmorning']
# ['arms', 'fine', 'cardiff']
# ['still', 'getting', 'goods']
# ['great', 'escape', 'fancy', 'bridge', 'needs', 'lager', 'tomo']
# ['claim', 'shopping', 'spree', 'call', 'mobstorequiz']
# ['sunshine', 'quiz', 'super', 'sony', 'recorder', 'canname', 'capital', 'australia', 'text', 'mquiz']
# ['getting', 'tickets', 'walsall', 'march', 'mate', 'getting', 'treat', 'want', 'terry']
# ['private', 'account', 'statement', 'shows', 'redeemed', 'points', 'call', 'identifier', 'code', 'expires']
# ['cthen', 'enuff', 'still', 'conclusion', 'contents', 'references', 'contents', 'cover']
# ['best', 'exam', 'later']
# ['important', 'customer', 'service', 'announcement', 'call', 'freephone']
# ['calls', 'messages', 'missed', 'calls']
# ['good', 'morning', 'dear', 'great', 'successful']
# ['prefer', 'free', 'days', 'tues', 'workin']
# ['days', 'making', 'dinner', 'tonite', 'invited']
# ['ffffffffff', 'alright', 'meet', 'sooner']
# ['want', 'mapquest', 'something', 'look', 'dogwood', 'drive']
# ['guaranteed', 'latest', 'nokia', 'phone', 'ipod', 'player', 'prize', 'word', 'collect', 'ibhltd', 'ldnw', 'mtmsgrcvd']
# ['love', 'little', 'pocy', 'bell', 'sorry', 'love']
# ['sent', 'many', 'many', 'messages', 'since', 'want', 'know', 'actually', 'getting', 'enjoy', 'rest']
# ['tuition', 'mind']
# ['gower', 'mate', 'good', 'wales', 'back', 'morrow', 'random']
# ['love', 'want', 'flood', 'pretty', 'pussy']
# ['number', 'live']
# ['happy', 'year', 'princess']
# ['sorry', 'cant', 'take', 'call', 'right', 'happens', 'waxsto', 'want', 'come', 'medical', 'insurance', 'able', 'deliver', 'basic', 'care', 'currently', 'shopping', 'right', 'medical', 'insurance', 'give', 'friday', 'morning', 'thats', 'major', 'person', 'guide', 'right', 'insurance']
# ['coming', 'back', 'dinner', 'rite', 'confirm']
# ['fine', 'sends', 'greetings']
# ['still', 'meeting', 'dinner', 'tonight']
# ['kate', 'lovely', 'tonight', 'phone', 'tomorrow', 'sing', 'gave', 'card']
# ['every', 'night', 'take', 'warm', 'bath', 'drink', 'milk', 'work', 'magic', 'still', 'need', 'loose', 'weight', 'know']
# ['mths', 'half', 'price', 'orange', 'line', 'rental', 'latest', 'camera', 'phones', 'free', 'phone', 'mths', 'call', 'mobilesdirect', 'free', 'update', 'stoptxt']
# ['okie', 'goin', 'drivin', 'shoppin']
# ['birth', 'mother', 'baby', 'brilliantly']
# ['guess', 'useless', 'calling', 'something', 'important']
# ['weaseling', 'shit', 'twice']
# ['pete', 'spain', 'recently', 'dinero', 'left', 'bill', 'said', 'rents', 'mayb', 'interested', 'around', 'james']
# ['fancy', 'shag', 'interested', 'sextextuk', 'xxuk', 'suzy', 'txts', 'cost', 'tncs', 'website']
# ['come']
# ['freemsg', 'call', 'claim', 'reward', 'hours', 'talk', 'time', 'phone', 'subscribe', 'mnth', 'stop', 'txtstop']
# ['done', 'oredi']
# ['stop', 'calling', 'everyone', 'saying', 'might', 'cancer', 'throat', 'hurts', 'talk', 'answering', 'everyones', 'calls', 'call', 'babysitting', 'monday']
# ['also', 'tell', 'said', 'happy', 'birthday']
# ['heard', 'anything', 'answering', 'texts', 'guessing', 'flaked', 'said', 'fantastic']
# ['heard', 'going', 'wildlife', 'talk', 'tonight', 'want', 'come', 'worzels', 'wizzle', 'whatever']
# ['cash', 'prize', 'prize', 'worth']
# ['cash', 'balance', 'currently', 'pounds', 'maximize', 'cash', 'send']
# ['olol', 'printed', 'forum', 'post', 'exact', 'prob', 'fixed', 'replacement', 'hopefully', 'dont', 'ignore']
# ['awarded', 'city', 'break', 'could', 'summer', 'shopping', 'spree', 'every', 'store', 'skilgme', 'tscs', 'winawk', 'perwksub']
# ['uncles', 'atlanta', 'wish', 'guys', 'great', 'semester']
# ['check', 'corect', 'speling', 'sarcasm']
# ['also', 'bringing', 'galileo', 'dobby']
# ['want', 'sent', 'mesages', 'today', 'thats', 'sorry', 'hurts']
# ['yeah', 'thinking']
# ['money', 'steve', 'mate']
# ['different', 'trying', 'find', 'every', 'real', 'life', 'photo', 'ever', 'took']
# ['sorry', 'roommates', 'took', 'forever', 'come']
# ['sell', 'tons', 'coins', 'sell', 'coins', 'someone', 'thru', 'paypal', 'voila', 'money', 'back', 'life', 'pockets']
# ['msgs', 'time', 'pass', 'silently', 'thinking', 'right', 'also', 'making', 'think', 'least', 'moment', 'drms', 'shesil']
# ['claire', 'havin', 'borin', 'time', 'alone', 'wanna', 'nite', 'chat', 'hope', 'claire', 'calls', 'minmoremobsemspobox']
# ['away', 'walk', 'slowly', 'kills', 'care', 'enough', 'stop']
# ['want', 'lick', 'pussy']
# ['happy', 'baby', 'alright', 'take', 'hope', 'fine', 'send', 'kiss', 'make', 'smile', 'across', 'kiss', 'kiss']
# ['grand', 'party', 'mention', 'cover', 'charge', 'probably', 'first', 'come', 'first', 'served']
# ['going', 'today', 'meeting']
# ['great', 'deal', 'farm', 'tour', 'deposit']
# ['unbelievable', 'faglord']
# ['trying', 'make', 'little', 'interesting']
# ['gonna', 'still', 'stock', 'tomorrow', 'today', 'trying', 'dubsack']
# ['urgent', 'attempt', 'contact', 'prize', 'yesterday', 'still', 'awaiting', 'collection', 'claim', 'call']
# ['aight', 'well', 'keep', 'informed']
# ['money', 'money', 'aint', 'thing']
# ['think', 'going', 'finn', 'come']
# ['unsubscribed', 'services', 'tons', 'sexy', 'babes', 'hunks', 'straight', 'phone', 'http', 'gotbabes', 'subscriptions']
# ['cash', 'prize', 'claim', 'call', 'rstm']
# ['tonight']
# ['receive', 'account', 'another', 'time', 'sorry', 'delay']
# ['voicemail', 'please', 'call']
# ['living', 'simple', 'loving', 'also', 'simple', 'laughing', 'simple', 'winning', 'tooo', 'simple', 'simple', 'difficult']
# ['give', 'food', 'preferably', 'slowly', 'loads', 'sugar', 'take', 'hour', 'give', 'water', 'slowly']
# ['heart', 'empty', 'without', 'love', 'mind', 'empty', 'without', 'wisdom', 'eyes', 'empty', 'without', 'dreams', 'life', 'empty', 'without', 'frnds', 'alwys', 'touch', 'good', 'night', 'sweet', 'dreams']
# ['neft', 'transaction', 'reference', 'number', 'decimal', 'credited', 'beneficiary', 'account', 'time']
# ['want', 'nice', 'shirt', 'hubby', 'nice', 'fiting', 'ones', 'budget', 'help', 'load', 'card', 'keep', 'posted']
# ['nothin', 'comes', 'mind', 'help', 'hanger', 'laptop', 'heavy']
# ['kallis', 'wont', 'play', 'first']
# ['sorry', 'call', 'later']
# ['reply', 'weekly', 'fifa', 'world', 'held', 'send', 'stop', 'service']
# ['haha', 'legs', 'neck', 'killing', 'amigos', 'hoping', 'night', 'burn', 'think', 'could', 'swing', 'like', 'hour']
# ['thats', 'weird', 'even', 'supposed', 'happening', 'good', 'idea', 'sure']
# ['late']
# ['like', 'later', 'though', 'whatever', 'feel', 'like']
# ['time', 'week', 'ryan']
# ['cine', 'better', 'need', 'plaza']
# ['auction', 'round', 'highest', 'next', 'maximum', 'send', 'bids', 'good', 'luck']
# ['juan', 'coming', 'home', 'course', 'expect', 'welcome', 'party', 'lots', 'presents', 'phone', 'back', 'loads', 'love', 'nicky']
# ['come']
# ['need', 'engin', 'arts', 'today']
# ['nothing']
# ['technical', 'support', 'providing', 'assistance', 'customer', 'call', 'email']
# ['please', 'kind', 'advice', 'please', 'come']
# ['badrith', 'chennai', 'surely', 'pick', 'competition']
# ['fine', 'anytime', 'best']
# ['subscriber', 'selected', 'receive', 'bonus', 'delivered', 'door', 'word', 'claim']
# ['sleep', 'well', 'take', 'rest']
# ['aight']
# ['good', 'afternoon', 'starshine', 'boytoy', 'crave', 'ache', 'fuck', 'sips', 'cappuccino', 'miss', 'babe', 'teasing', 'kiss']
# ['want', 'video', 'phone', 'anytime', 'network', 'mins', 'half', 'price', 'line', 'rental', 'free', 'text', 'months', 'reply', 'call', 'free', 'delivery']
# ['also', 'track', 'lighters', 'find']
# ['oclock', 'mine', 'bash', 'flat', 'plan']
# ['even', 'friend', 'priest', 'call']
# ['dont', 'search', 'love', 'love', 'find', 'thats', 'called', 'falling', 'love', 'bcoz', 'dont', 'force', 'fall', 'know', 'smeone', 'hold', 'bslvyl']
# ['first', 'time', 'history', 'need', 'comfort', 'luxury', 'sold', 'price', 'india', 'onion', 'petrol', 'beer', 'shesil']
# ['call', 'germany', 'pence', 'minute', 'call', 'fixed', 'line', 'access', 'number', 'prepayment', 'direct', 'access']
# ['superb', 'thought', 'grateful', 'dont', 'everything', 'want', 'means', 'still', 'opportunity', 'happier', 'tomorrow', 'today']
# ['still', 'looking', 'gone', 'driving', 'test']
# ['tell', 'thinking', 'plus', 'going', 'stop', 'runs']
# ['themob', 'comes', 'selection', 'downloads', 'members', 'free', 'click', 'open', 'next', 'link', 'sent', 'fone']
# ['friend']
# ['mark', 'taking', 'forever', 'pick', 'prescription', 'pain', 'coming', 'back']
# ['request', 'maangalyam', 'alaipayuthe', 'callertune', 'callers', 'press', 'copy', 'friends', 'callertune']
# ['sorry', 'battery', 'died', 'yeah']
# ['hiya', 'hows', 'going', 'sunny', 'africa', 'hope', 'avin', 'good', 'time', 'give', 'silver', 'back', 'kiss']
# ['argh', 'spotty', 'anyway', 'thing', 'remember', 'research', 'province', 'sterling', 'problem', 'free', 'places', 'looked']
# ['change', 'also']
# ['know', 'girls', 'always', 'safe', 'selfish', 'know', 'thank', 'good', 'night']
# ['sorry', 'flaked', 'last', 'night', 'shit', 'seriously', 'goin', 'roommate', 'tonight']
# ['trip', 'quite', 'tiring', 'starts', 'today', 'taking', 'modules', 'concentrating', 'final', 'project']
# ['sorry', 'call', 'later']
# ['send', 'resume']
# ['promise', 'getting', 'soon', 'text', 'morning', 'know', 'made']
# ['says', 'hurry', 'hell']
# ['accordin', 'discussed', 'yest', 'except', 'much', 'lesson', 'attend']
# ['surly', 'give', 'coming', 'review']
# ['finish', 'lunch', 'home', 'stay', 'today']
# ['call', 'lunch']
# ['lost', 'pounds', 'since', 'visit', 'last', 'week', 'woot', 'woot', 'gonna', 'celebrate', 'stuffing', 'face']
# ['bugis', 'near']
# ['career', 'added', 'contact', 'indyarocks', 'send', 'free', 'remove', 'phonebook']
# ['shall', 'fine', 'avalarr', 'hollalater']
# ['working', 'technical', 'support', 'voice', 'process', 'networking', 'field']
# ['thanks', 'temales', 'wonderful', 'thank', 'great', 'week']
# ['town', 'alone']
# ['poly', 'tones', 'mobs', 'direct', 'rply', 'poly', 'title', 'poly', 'breathe', 'titles', 'crazyin', 'sleepingwith', 'finest', 'ymca', 'getzed', 'pobox']
# ['wait', 'till', 'pick']
# []
# ['sorry', 'mail']
# ['called', 'pick', 'phone', 'already', 'said']
# ['lost', 'kilos', 'today']
# ['make', 'tonight']
# ['picking', 'various', 'points']
# ['alright', 'tyler', 'minor', 'crisis', 'home', 'sooner', 'thought', 'asap']
# ['already', 'flaky', 'parent', 'snot', 'supposed', 'child', 'support', 'parent', 'ride', 'anyway', 'supposed', 'support', 'hurt', 'unintentional', 'hurt', 'nonetheless']
# ['indians', 'nice', 'kane', 'shud', 'drink', 'sometime', 'soon', 'mite', 'works', 'laugh', 'soon', 'love', 'pete']
# ['small', 'boost', 'secret', 'energy']
# ['stayin', 'trouble', 'stranger', 'dave', 'sorted', 'still', 'bloke', 'gona', 'girl', 'still', 'thinks', 'getha']
# ['aight', 'lemme', 'know']
# ['scotland', 'hope', 'showing', 'tendencies', 'take', 'care', 'live', 'dream']
# ['many', 'licks', 'take', 'center', 'tootsie']
# ['write']
# ['free', 'week', 'entry', 'textpod', 'chance', 'ipod', 'cash', 'every', 'vpod', 'textpod', 'custcare']
# ['actually', 'sleeping', 'still', 'might', 'call', 'back', 'text', 'rock', 'send', 'text', 'wake']
# ['tmrw', 'finishing', 'doors']
# ['love', 'give', 'massages', 'lots', 'baby', 'fave', 'position']
# ['send', 'someone', 'else']
# ['still', 'attending', 'talks']
# ['messages', 'phone', 'holding']
# ['dont', 'worry', 'lambu', 'come', 'enjoy', 'batchlor', 'party']
# ['auction', 'brand', 'nokia', 'auction', 'today', 'auction', 'free', 'join', 'take', 'part', 'nokia']
# ['thats', 'late', 'well', 'good', 'night', 'give', 'call', 'tomorrow', 'going', 'sleep', 'night', 'night']
# ['switch', 'fone', 'dammit']
# ['aiyo', 'always', 'dunno', 'reply', 'first', 'time', 'reply', 'fast', 'lucky', 'workin', 'sugardad']
# ['nothing', 'really', 'making', 'sure', 'everybody', 'speed']
# ['boys', 'want', 'pics', 'sent', 'direct', 'phone', 'porn', 'free', 'stop', 'text', 'stopbcm']
# ['guaranteed', 'award', 'maybe', 'even', 'cash', 'claim', 'award', 'call', 'free', 'legitimat', 'efreefone', 'number', 'think']
# ['cool', 'cool', 'chikku', 'chikku']
# ['want', 'custom', 'officer', 'discount']
# ['call', 'landline', 'number', 'asked', 'come', 'anna', 'nagar', 'afternoon']
# ['need', 'presnts', 'always', 'cant', 'love', 'jeevithathile', 'irulinae', 'neekunna', 'prakasamanu', 'sneham', 'prakasam', 'ennal', 'prabha', 'prabha', 'love', 'dont']
# ['take', 'member', 'said', 'aunt', 'flow', 'visit', 'months', 'cause', 'developed', 'ovarian', 'cysts', 'shrink']
# ['checked', 'heading', 'drop', 'stuff']
# ['tomorrow', 'onwards', 'work']
# ['mobiles', 'must', 'nokia', 'collect', 'today', 'optout', 'mtmsg', 'txtauction']
# ['tall', 'princess']
# ['opinion', 'jada', 'kusruthi', 'lovable', 'silent', 'character', 'matured', 'stylish', 'simple', 'reply']
# ['alfie', 'moon', 'children', 'need', 'song', 'tell', 'tone', 'charity', 'nokias', 'poly', 'charity', 'polys', 'profit', 'charity']
# ['think', 'need', 'going', 'late', 'school', 'night', 'especially', 'class', 'missed', 'last', 'wednesday', 'probably', 'failed', 'test', 'friday']
# ['belly', 'laugh', 'tomo']
# ['working', 'eyes', 'philosophy', 'text', 'later', 'free', 'chat']
# ['haha', 'cant', 'forfeit', 'haha']
# ['congratulations', 'claim', 'tickets', 'concert', 'november', 'gift', 'guaranteed', 'call', 'claim', 'smsco', 'cost']
# ['message', 'text', 'missing', 'sender', 'name', 'missing', 'number', 'missing', 'sent', 'date', 'missing', 'missing', 'thats', 'everything', 'missing', 'sent', 'fullonsms']
# ['private', 'account', 'statement', 'shows', 'redeemed', 'points', 'call', 'identifier', 'code', 'expires']
# ['vikky', 'come', 'around', 'time']
# ['need', 'wait', 'rain', 'stop']
# ['gumby', 'special', 'cheese', 'pizza', 'know', 'doin', 'tonight']
# ['never', 'blame', 'life', 'good', 'days', 'give', 'happiness', 'days', 'give', 'experience', 'essential', 'life', 'gods', 'blessings', 'good', 'morning']
# ['urgent', 'trying', 'contact', 'todays', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'land', 'line', 'claim']
# ['secret', 'admirer', 'looking', 'make', 'contact', 'find', 'reveal', 'thinks', 'special', 'call']
# ['moby', 'quiz', 'high', 'street', 'prize', 'know', 'duchess', 'cornwall', 'first', 'name', 'unsub', 'stop']
# ['training', 'manual', 'show', 'tech', 'process', 'password', 'reset', 'troubleshooting']
# ['indeed', 'either']
# ['okie']
# ['dear', 'dave', 'final', 'notice', 'collect', 'tenerife', 'holiday', 'cash', 'award', 'call', 'landline']
# ['would', 'back', 'maybe', 'today', 'told', 'direct', 'link', 'getting', 'cars', 'bids', 'online', 'arrange', 'shipping', 'partnership', 'invest', 'money', 'shipping', 'takes', 'care', 'rest', 'self', 'reliant', 'soon', 'worry']
# ['shuhui', 'bought', 'present', 'swatch', 'watch']
# ['club', 'dont', 'fink', 'please', 'leave', 'area', 'reply', 'promised', 'carlie', 'calls', 'minmobsmore', 'lkpobox']
# ['mine', 'like', 'china', 'noisy']
# ['themob', 'link', 'premium', 'pink', 'panther', 'game', 'sugababes', 'crazy', 'zebra', 'animation', 'badass', 'hoody', 'wallpaper', 'free']
# []
# ['kate', 'jackson', 'center', 'right']
# ['come']
# ['dont', 'care', 'need', 'princess']
# ['write', 'dictionary', 'mode', 'cover', 'screen', 'hand', 'press', 'gently', 'remove', 'hand', 'interesting']
# ['dont', 'pack', 'store', 'like', 'cereals', 'must', 'pack', 'food', 'pack', 'gari', 'something', 'miss']
# ['polyphonic', 'tone', 'every', 'week', 'tone', 'free', 'txtin', 'tell', 'friends', 'tone', 'reply', 'info']
# ['customer', 'loyalty', 'offer', 'nokia', 'mobile', 'txtauction', 'word', 'start', 'ctxt', 'mtmsg']
# ['night', 'going', 'swing']
# ['oops']
# ['thanx', 'goodmate', 'think', 'rite', 'sary', 'asusual', 'cheered', 'love', 'franyxxxxx']
# ['shower', 'baby']
# ['dont', 'search', 'love', 'love', 'find', 'thats', 'called', 'falling', 'love', 'bcoz', 'dont', 'force', 'fall', 'know', 'smeone', 'hold', 'bslvyl']
# ['trust', 'even']
# ['mine', 'welcome', 'come']
# ['friendship', 'game', 'play', 'word', 'start', 'march', 'ends', 'tomorrow', 'yesterday', 'today']
# ['reached', 'home', 'tired', 'come', 'tomorro']
# ['justbeen', 'overa', 'week', 'since', 'broke', 'already', 'brains', 'going', 'mush']
# ['customer', 'loyalty', 'offer', 'nokia', 'mobile', 'txtauction', 'word', 'start', 'ctxt', 'mtmsg']
# ['sian', 'meeting', 'supervisor', 'work', 'liao', 'working']
# ['call', 'listen', 'extreme', 'dirty', 'live', 'chat', 'going', 'office', 'right', 'total', 'privacy', 'knows', 'listening']
# ['stuff', 'sell', 'tell']
# ['charges', 'transfer', 'charges', 'withdraw', 'anyhow', 'like']
# ['honey', 'sweetheart', 'darling', 'sexy', 'buns', 'sugar', 'plum', 'loverboy', 'miss', 'boytoy', 'smacks']
# ['stupid', 'always', 'sending', 'like', 'believe', 'message', 'pandy', 'mental']
# ['nice', 'impressively', 'sensible', 'went', 'home', 'early', 'feel', 'fine', 'boring', 'remember']
# ['loan', 'purpose', 'homeowners', 'tenants', 'welcome', 'previously', 'refused', 'still', 'help', 'call', 'free', 'text', 'back', 'help']
# ['onion', 'roast']
# ['year', 'yetunde', 'said', 'wanted', 'surprise', 'didnt', 'money', 'returned', 'january', 'return', 'period', 'ended']
# ['nervous']
# ['shopping', 'raining', 'hard', 'leave', 'orchard']
# ['want', 'sent', 'mesages', 'today', 'thats', 'sorry', 'hurts']
# ['reached', 'home', 'bathe', 'first', 'using', 'tell', 'finishes']
# ['todays', 'class']
# ['saying', 'explicitly', 'told', 'nora', 'know', 'someone', 'probably', 'gonna', 'bother']
# ['hello', 'orange', 'month', 'free', 'access', 'games', 'news', 'sport', 'plus', 'free', 'texts', 'photo', 'messages', 'reply', 'terms', 'apply', 'orange']
# ['poking', 'everyday', 'teach', 'canada', 'saying']
# ['freemsg', 'records', 'indicate', 'entitled', 'pounds', 'accident', 'claim', 'free', 'reply', 'text', 'stop']
# []
# ['floppy', 'snappy', 'happy', 'chat', 'service', 'photo', 'upload', 'call', 'stop', 'texts', 'call']
# ['make', 'stuff', 'happens', 'everything', 'else', 'pushes', 'edge', 'underdtand', 'often', 'sorry', 'sorry', 'life']
# ['like', 'made', 'throw', 'smoking', 'friend', 'time', 'awesome']
# ['picking']
# ['well', 'meant', 'opposed', 'drunken', 'night']
# ['took', 'hooch', 'walk', 'toaday', 'fell', 'splat', 'grazed', 'knees', 'everything', 'stayed', 'home', 'tomorrow']
# ['time', 'especially', 'since', 'american', 'like', 'minutes', 'long', 'stop', 'singing']
# ['fine', 'thanks']
# ['easy', 'selected', 'means', 'good']
# ['come', 'quick', 'cant', 'bare']
# ['hand', 'phone', 'chat']
# ['early', 'dinner', 'outside', 'izzit']
# ['free', 'week', 'nokia', 'tone', 'every', 'week', 'nokia', 'txting', 'tell', 'mates', 'getzed', 'pobox', 'norm', 'tone']
# ['late', 'need', 'laptop']
# ['awake', 'snow']
# ['message', 'call']
# ['taking', 'quick', 'shower', 'epsilon', 'like']
# ['nokia', 'tone', 'every', 'week', 'tone', 'free', 'txtin', 'tell', 'friends', 'tone', 'reply', 'info']
# ['neshanth']
# ['call', 'finish', 'come', 'pick']
# ['month', 'kotees', 'birthday', 'know']
# ['stand', 'away', 'heart', 'ache', 'without', 'wonder', 'crave']
# ['reassuring', 'crazy', 'world']
# ['plane', 'give', 'month']
# ['message']
# ['moved', 'would', 'great', 'come']
# ['gent', 'trying', 'contact', 'last', 'weekends', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'claim', 'code', 'valid']
# ['sorry', 'call', 'later']
# ['many', 'days', 'since']
# ['urgent', 'mobile', 'bonus', 'caller', 'prize', 'attempt', 'reach', 'call', 'asap']
# ['well', 'confuses', 'things', 'doesnt', 'thought', 'friends', 'maybe', 'wrong', 'thing', 'already', 'sort', 'invited', 'come', 'money']
# ['worry', 'pieces', 'cloth', 'pack', 'also', 'take', 'tablets']
# ['double', 'mins', 'double', 'price', 'linerental', 'latest', 'orange', 'bluetooth', 'mobiles', 'call', 'mobileupd', 'latest', 'offers', 'call', 'optout']
# ['parents', 'gettin', 'cash', 'good', 'news', 'picked', 'downstem']
# ['telling', 'tell', 'treat']
# ['chinese', 'food', 'paying', 'lipo']
# ['wondering', 'would', 'okay', 'call', 'uncle', 'john', 'know', 'things', 'nigeria', 'dollars', 'years', 'sent', 'know', 'strain', 'plan', 'back', 'every', 'dime', 'gives', 'every', 'dime', 'expect', 'anything', 'practical', 'something', 'like']
# ['shadow', 'early', 'spring']
# ['whole', 'appreciated', 'last', 'reading', 'semi', 'argument', 'apart', 'things', 'going']
# ['winner', 'specially', 'selected', 'receive', 'cash', 'award', 'speak', 'live', 'operator', 'claim', 'call', 'cost']
# ['done']
# ['congratulations', 'awarded', 'vouchers', 'gift', 'guaranteed', 'free', 'entry', 'wkly', 'draw', 'music', 'tncs', 'ldew', 'ppmx']
# ['gotta', 'drive', 'back', 'butt', 'sore']
# ['login', 'time', 'fetching', 'home']
# ['shall', 'bring', 'bottle', 'wine', 'keep', 'amused', 'joking', 'still', 'bring', 'bottle', 'white', 'tomorrow']
# ['food', 'fridge', 'want', 'meal', 'tonight']
# ['best', 'congrats']
# ['next', 'make']
# ['burger', 'king', 'wanna', 'play', 'footy', 'stadium', 'burger', 'king', 'sept', 'large', 'super', 'coca', 'cola', 'walk', 'winner']
# ['thing', 'good', 'thanx', 'exams', 'march', 'done', 'revision', 'fran', 'still', 'boyf', 'gotta', 'interviw', 'exeter', 'worried']
# ['helloooo', 'wake', 'sweet', 'morning', 'welcomes', 'enjoy', 'full', 'mrng']
# ['long', 'exhausted', 'want', 'cuddle', 'take']
# ['house', 'maid', 'murderer', 'murdered', 'january', 'public', 'holiday', 'govt', 'instituitions', 'closed', 'including', 'post', 'office']
# ['gonna', 'death', 'gonna', 'leave', 'note', 'says', 'robs', 'fault', 'avenge']
# ['done']
# ['come', 'room', 'point', 'iron', 'plan', 'weekend']
# ['urgent', 'mobile', 'number', 'awarded', 'prize', 'guaranteed', 'call', 'land', 'line', 'claim', 'valid']
# ['like', 'talk', 'able', 'dont', 'know']
# ['still', 'coffee', 'frens', 'fren', 'drove', 'give', 'lift']
# ['glad', 'reply']
# ['donno', 'scorable']
# ['ofcourse', 'also', 'upload', 'songs']
# ['baby', 'back', 'work', 'wanting', 'allday', 'hope', 'didnt', 'piss', 'phone', 'today', 'give', 'call']
# ['shoot', 'docs', 'waiting', 'room']
# ['still', 'painting', 'wall']
# []
# ['superior', 'telling', 'friday', 'leave', 'department', 'except', 'leave', 'call', 'waheed', 'fathima', 'conform']
# ['paragon', 'havent', 'decided', 'whether']
# ['going', 'college', 'else', 'come', 'self']
# []
# ['warner', 'village', 'colin', 'farrell', 'swat', 'wkend', 'warner', 'village', 'free', 'popcorn', 'show', 'ticket', 'kiosk', 'valid', 'kiosk', 'reply', 'sony', 'film', 'offers']
# ['gonna', 'ring']
# ['taking', 'half', 'leave', 'well']
# ['want', 'snow', 'freezing', 'windy']
# ['check', 'mail', 'mailed', 'varma', 'kept', 'copy', 'regarding', 'membership', 'take', 'care', 'insha', 'allah']
# ['deus', 'game', 'comin', 'early', 'next']
# ['watching', 'ajith', 'film']
# ['babe', 'chloe', 'smashed', 'saturday', 'night', 'great', 'weekend', 'missing', 'visionsms', 'text', 'stop', 'stop', 'text']
# []
# ['mean', 'left', 'early', 'check', 'working']
# ['yeah', 'gang', 'ready']
# ['need', 'cash', 'nitros', 'hurry', 'come', 'crash']
# ['gotta']
# ['babe', 'friend', 'cancel', 'still', 'visit']
# ['sorry', 'meeting', 'call', 'later']
# ['lots', 'used', 'ones', 'babe', 'model', 'help', 'youi', 'bring', 'match']
# ['drive', 'read', 'need', 'write']
# ['school', 'starting', 'stay', 'weather', 'like', 'food', 'social', 'support', 'system', 'like', 'friends', 'school', 'things', 'important']
# ['gettin', 'arty', 'collages', 'well', 'tryin', 'roast', 'lovely', 'shall', 'enjoy']
# ['aight', 'rush']
# ['went', 'oredi']
# ['message', 'free', 'welcome', 'improved', 'dogging', 'club', 'unsubscribe', 'service', 'reply', 'stop', 'msgs']
# ['well', 'like', 'actually', 'called', 'someone', 'punto', 'woulda', 'worse']
# ['alright', 'good', 'night']
# ['single', 'line', 'meaning', 'miss', 'anything', 'best', 'life']
# ['story', 'last', 'week', 'wife', 'wish', 'parents', 'forgot', 'kids', 'went', 'work', 'even', 'colleagues', 'wish']
# ['talk', 'sexy', 'make', 'friends', 'fall', 'love', 'worlds', 'discreet', 'text', 'dating', 'service', 'text', 'could', 'meet']
# ['chatting']
# ['sent', 'part']
# ['back', 'tampa', 'west', 'palm', 'hear', 'happened']
# ['perpetual']
# ['sore', 'throat', 'scratches', 'talk']
# ['received', 'understood', 'acted', 'upon']
# ['hamster', 'dead', 'meet', 'orchard']
# ['guess', 'worried', 'must', 'know', 'body', 'repairs', 'quite', 'sure', 'worry', 'take', 'slow', 'first', 'tests', 'guide', 'ovulation', 'relax', 'nothing', 'said', 'reason', 'worry', 'keep', 'followin']
# ['program', 'slacking']
# ['full', 'heat', 'applyed']
# ['freemsg', 'xmas', 'tones', 'reply', 'real']
# ['designation', 'software', 'developer', 'chennai']
# ['awesome', 'minute']
# ['haha', 'hopefully', 'lose', 'orchard', 'weigh']
# ['alrite', 'girl', 'know', 'gail', 'neva', 'wrong', 'take', 'care', 'sweet', 'worry', 'love', 'yaxxx']
# ['come', 'soon', 'come', 'otherwise', 'tomorrow']
# ['online', 'transaction']
# ['head', 'swell', 'thanks', 'making']
# ['played', 'smash', 'bros', 'religiously']
# ['urgent', 'costa', 'holiday', 'await', 'collection', 'call', 'toclaim', 'pobox', 'stockport', 'cost', 'mins']
# ['guess', 'happy', 'clover', 'whatever', 'saying']
# ['urgent', 'mobile', 'number', 'bonus', 'caller', 'prize', 'attempt', 'reach', 'call', 'asap']
# ['chances', 'cash', 'pounds', 'send', 'cost', 'days', 'tsandcs', 'apply', 'reply', 'info']
# ['many', 'model', 'sony', 'ericson', 'also', 'luks', 'good', 'forgot', 'modl']
# ['sent', 'webadres', 'geting', 'salary', 'slip']
# ['birthday', 'today', 'wish', 'oscar']
# ['geeeee', 'internet', 'really', 'today']
# ['nope', 'waiting', 'daddy']
# ['still', 'buff']
# ['private', 'account', 'statement']
# ['oops', 'phone', 'died', 'even', 'know', 'yeah', 'like', 'better']
# ['true', 'dear', 'pray', 'evening', 'felt', 'time']
# ['finishing', 'soon']
# ['everywhere', 'dirt', 'floor', 'windows', 'even', 'shirt', 'sometimes', 'open', 'mouth', 'comes', 'flowing', 'dream', 'world', 'without', 'half', 'chores', 'time', 'lots', 'shows', 'guess', 'like', 'things', 'must', 'exist', 'like', 'rain', 'hail', 'mist', 'time', 'done', 'become']
# ['anything']
# ['raji', 'favour', 'convey', 'birthday', 'wishes', 'nimya', 'today', 'birthday']
# ['yeah', 'hopefully', 'tyler', 'could', 'maybe', 'around']
# ['babe', 'want', 'dont', 'baby', 'nasty', 'thing', 'filthyguys', 'fancy', 'rude', 'time', 'sexy', 'bitch', 'hard', 'msgs']
# []
# ['review', 'keep', 'fantastic', 'nokia', 'gage', 'game', 'deck', 'club', 'nokia', 'cnupdates', 'newsletter', 'unsubscribe', 'alerts', 'reply', 'word']
# ['well', 'pattern', 'emerging', 'friends', 'telling', 'drive', 'come', 'smoke', 'telling', 'weed', 'fiend', 'make', 'smoke', 'much', 'impede', 'things', 'hesitant']
# ['gonna', 'specific']
# ['please', 'dont', 'like']
# ['good', 'trip', 'watch', 'remember', 'back', 'must', 'decide', 'easter']
# ['feeling', 'sleepy', 'today', 'shall', 'dear']
# ['hello', 'sort', 'town', 'already', 'dont', 'rush', 'home', 'eating', 'nachos', 'know']
# ['watching']
# ['rajini', 'comes']
# ['weightloss', 'girl', 'friends', 'make', 'loads', 'money', 'ebay', 'something', 'give', 'thanks']
# ['might', 'come', 'kerala', 'days', 'prepared', 'take', 'leave', 'finalise', 'dont', 'plan', 'travel', 'visit', 'need', 'finish', 'urgent', 'works']
# ['stop', 'club', 'tones', 'replying', 'stop', 'tone', 'enjoy', 'html', 'terms', 'club', 'tones', 'cost', 'week']
# ['please', 'call', 'customer', 'service', 'representative', 'freephone', 'guaranteed', 'cash', 'prize']
# ['enjoy', 'urself']
# ['happy', 'birthday', 'find', 'prince', 'charming', 'soon', 'work', 'hard']
# ['account', 'refilled', 'successfully', 'decimal', 'keralacircle', 'prepaid', 'account', 'balance', 'decimal', 'transaction']
# ['told', 'coming', 'wednesday']
# ['absolutely', 'love', 'south', 'park', 'recently', 'started', 'watching', 'office']
# ['tell', 'friend', 'sure', 'want', 'live', 'smokes', 'much', 'spend', 'hours', 'begging', 'come', 'smoke']
# ['lunch', 'come', 'quickly', 'open', 'door']
# ['esplanade', 'mind', 'giving', 'lift', 'today']
# ['uhhhhrmm', 'isnt', 'test', 'youre', 'sick']
# ['hall', 'asked', 'girl', 'tell', 'starting', 'term', 'answer', 'manage', 'hesitation', 'lookin', 'around', 'silently', 'said', 'intha', 'ponnungale', 'ipaditan']
# ['dear', 'umma', 'called']
# ['want', 'send', 'virtual', 'need']
# ['think', 'smart', 'week', 'weekly', 'quiz', 'text', 'play', 'winnersclub', 'week']
# ['looks', 'scrumptious', 'daddy', 'wants', 'night', 'long']
# ['march', 'ending', 'ready', 'call', 'sure', 'problem', 'capital', 'never', 'complete', 'work', 'ladies']
# ['posted', 'couple', 'pics', 'still', 'snow', 'outside', 'waking']
# ['change', 'windows', 'logoff', 'sound']
# ['goodmorning', 'free', 'call']
# ['yesterday', 'going', 'home']
# ['move', 'morphine']
# ['course', 'messages', 'messenger', 'sending']
# ['sorry', 'chikku', 'cell', 'problem', 'thts', 'able', 'reply']
# ['shame', 'maybe', 'meet', 'tomo']
# ['live', 'fantasies', 'call', 'croydon', 'national', 'rate', 'call']
# ['today', 'accept', 'accept', 'brother', 'sister', 'lover', 'dear', 'best', 'clos', 'lvblefrnd', 'jstfrnd', 'cutefrnd', 'lifpartnr', 'belovd', 'swtheart', 'bstfrnd', 'rply', 'means', 'enemy']
# ['downloaded', 'file', 'installing']
# ['know', 'anthony', 'bringing', 'money', 'school', 'fees', 'rent', 'stuff', 'like', 'thats', 'need', 'help', 'friend', 'need']
# ['guys', 'dolls', 'last', 'night', 'patrick', 'swayze', 'great']
# ['free', 'week', 'nokia', 'tone', 'every', 'week', 'nokia', 'txting', 'tell', 'mates', 'getzed', 'pobox', 'norm', 'tone']
# ['pleased', 'inform', 'application', 'airtel', 'broadband', 'processed', 'successfully', 'installation', 'happen', 'within', 'days']
# ['alright', 'bring', 'like', 'mins']
# ['sorry', 'left', 'phone', 'upstairs', 'might', 'hectic', 'would', 'birds', 'fell', 'swoop', 'date']
# ['deleted', 'contact']
# ['woke', 'yeesh', 'late', 'fall', 'asleep']
# ['school', 'send', 'ashley', 'number']
# ['coffee', 'cake', 'guess']
# ['making', 'pics', 'bigger']
# ['still', 'online', 'finished', 'formatting']
# ['voicemail', 'please', 'call']
# ['movie', 'call']
# ['broke', 'list', 'reasons', 'nobody', 'town', 'tell', 'sarcastic', 'faggy']
# ['going', 'lesson']
# ['subscribed', 'best', 'mobile', 'content', 'service', 'days', 'send', 'stop', 'helpline']
# ['working', 'ringing', 'thing', 'whole', 'houseful', 'screaming', 'brats', 'pulling', 'hair', 'loving']
# ['told', 'name', 'gautham']
# ['receiving', 'week', 'triple', 'echo', 'ringtone', 'shortly', 'enjoy']
# ['going', 'film', 'sorry']
# []
# ['spile', 'seven', 'broad', 'canal']
# ['tirupur', 'call']
# ['joanna', 'freaking', 'looked', 'thru', 'friends', 'find', 'photos', 'asking', 'stuff', 'myspace', 'even', 'logged', 'like', 'year']
# ['tired', 'slept', 'well', 'past', 'nights']
# ['refused', 'loan', 'secured', 'unsecured', 'credit', 'call', 'free', 'text', 'back', 'help']
# ['india', 'going', 'draw', 'series', 'many', 'years', 'south', 'african', 'soil']
# ['natalja', 'inviting', 'friend', 'reply', 'stop', 'send', 'stop', 'frnd']
# ['help', 'tell', 'ashley', 'cant', 'find', 'number']
# ['okay', 'wait']
# ['seeing']
# ['hmph', 'head', 'baller']
# ['library']
# ['free', 'call']
# ['weekend', 'fine', 'excuse', 'much', 'decorating']
# ['meeting']
# ['yeah', 'great', 'time', 'newquay', 'send', 'postcard', 'look', 'girls', 'gone', 'know', 'talkin', 'bout']
# ['thanx']
# ['want', 'bold', 'torch']
# ['funeral', 'home', 'audrey']
# ['details', 'later']
# ['popped', 'bout', 'something', 'said', 'around', 'tonght', 'girl', 'comes']
# ['jade', 'paul', 'remember', 'barmed', 'want', 'talk']
# ['hard', 'true', 'much', 'show', 'express', 'love', 'someone', 'much', 'hurt', 'leave', 'seperated', 'evening']
# ['entry', 'weekly', 'comp', 'chance', 'ipod', 'entry', 'rate', 'apply', 'details']
# ['want', 'thing']
# ['miss', 'someone']
# ['meant', 'calculation', 'units', 'school', 'really', 'expensive', 'started', 'practicing', 'accent', 'important', 'decided', 'years', 'dental', 'school', 'nmde', 'exam']
# ['come', 'home', 'half', 'hour']
# ['called', 'hoping', 'malaria', 'know', 'miss', 'guys', 'miss', 'bani', 'give', 'love', 'especially', 'great']
# ['really', 'still', 'tonight', 'babe']
# ['sent', 'scream', 'moan', 'princess']
# ['joking']
# ['petey', 'whereare', 'friendsare', 'thekingshead', 'come', 'canlove']
# ['bored', 'lecturer', 'repeating', 'last', 'weeks', 'stuff', 'waste', 'time']
# ['okey', 'doke', 'home', 'dressed', 'laying', 'around', 'speak', 'later', 'bout', 'times', 'stuff']
# ['take', 'test']
# ['told', 'number', 'gautham']
# ['thank', 'much', 'skyped', 'sura', 'didnt', 'pleasure', 'company', 'hope', 'good', 'given', 'ultimatum', 'countin', 'aburo', 'enjoy']
# ['great', 'safe', 'trip', 'dont', 'panic', 'surrender']
# ['waiting', 'reach', 'home', 'already']
# ['como', 'listened', 'plaid', 'album', 'quite', 'hilarious', 'also', 'bought', 'braindance', 'comp', 'ofstuff', 'aphex', 'abel']
# ['friends', 'stay', 'chat']
# ['step', 'outta', 'congrats']
# ['pretty', 'lady', 'like', 'single']
# ['tell', 'something', 'thats', 'okay']
# ['money', 'wining', 'number', 'next']
# ['look', 'beautiful', 'intelligent', 'woman', 'like', 'know', 'like', 'like', 'worry']
# ['schedule']
# ['feel', 'like', 'john', 'lennon']
# ['splashmobile', 'choose', 'tones', 'subscrition', 'service', 'weekly', 'tones', 'costing', 'credit', 'kick', 'back', 'enjoy']
# ['excellent', 'riley', 'plans']
# ['abeg', 'make', 'profit', 'start', 'using', 'sponsors', 'next', 'event']
# ['argh', 'fuck', 'nobody', 'town']
# ['guaranteed', 'cash', 'prize', 'claim', 'prize', 'call', 'customer', 'service', 'representative']
# []
# ['havent', 'planning', 'later', 'check', 'already', 'lido', 'show', 'afternoon', 'finish', 'work', 'already']
# ['babe', 'likely', 'sorry', 'tonight', 'really', 'wanna', 'tomorrow', 'call', 'love']
# ['better', 'quickly', 'bathe', 'settle']
# ['quite', 'know', 'still', 'hold', 'anyone', 'pick', 'bout']
# ['xmas', 'story', 'peace', 'xmas', 'love', 'xmas', 'miracle', 'jesus', 'blessed', 'month', 'ahead', 'wish', 'merry', 'xmas']
# ['beautiful', 'truth', 'gravity', 'read', 'carefully', 'heart', 'feels', 'light', 'someone', 'feels', 'heavy', 'someone', 'leaves', 'good', 'night']
# ['motivate', 'behind', 'every', 'darkness', 'shining', 'light', 'waiting', 'find', 'behind', 'every', 'best', 'friend', 'always', 'trust', 'love', 'bslvyl']
# ['leaving', 'house']
# ['class', 'hours', 'sorry']
# ['blackberry', 'bold', 'torch', 'used', 'know', 'plus', 'saying', 'wifi', 'ipad', 'saying']
# ['like']
# ['msgs', 'chat', 'free', 'hardcore', 'services', 'text', 'nothing', 'must', 'verify', 'network']
# ['believe', 'true', 'incredible', 'txts', 'reply', 'learn', 'truly', 'amazing', 'things', 'blow', 'mind']
# ['cool', 'come', 'havent', 'wined', 'dined']
# ['sorry', 'light', 'turned', 'green', 'meant', 'another', 'friend', 'wanted', 'worth', 'around']
# ['urgent', 'week', 'free', 'membership', 'prize', 'jackpot', 'word', 'claim', 'dbuk', 'lccltd', 'pobox', 'ldnw']
# ['sorry', 'went', 'early', 'nightnight']
# ['yeah', 'clearly', 'fault']
# ['break', 'accommodationvouchers', 'terms', 'conditions', 'apply', 'claim', 'mustprovide', 'claim', 'number']
# ['called', 'oredi']
# ['somebody', 'website', 'play', 'hold', 'using', 'online', 'spacebucks']
# ['early', 'bird', 'purchases']
# ['captain', 'vijaykanth', 'comedy', 'captain', 'drunken']
# ['good', 'morning', 'princess', 'great']
# ['lovely', 'night']
# ['please', 'dollar', 'loan', 'back', 'february']
# ['slept', 'thinkthis', 'time', 'dangerous']
# ...
# ['think', 'mentor', 'percent', 'sure']
# ['yeah', 'open', 'chat', 'click', 'friend', 'lists', 'make', 'list', 'easy']
# ['aight', 'pick', 'open', 'tonight']
# ['send', 'yetty', 'number']
# ['dont', 'know']
# ['sent', 'scores', 'sophas', 'secondary', 'application', 'schools', 'think', 'thinking', 'applying', 'research', 'cost', 'also', 'contact', 'joke', 'ogunrinde', 'school', 'less', 'expensive', 'ones']
# ['stupid', 'auto', 'correct', 'phone']
# ['want', 'tuesday', 'meals', 'gravy', 'mark']
# ['sorry', 'uncle', 'keep', 'touch']
# ['download', 'fring']
# ['yetunde', 'sorry', 'moji', 'seem', 'busy', 'able', 'shopping', 'please', 'find', 'wanted', 'please', 'forgive', 'reply', 'free', 'yahoo', 'messenger']
# ['also', 'dont', 'reply']
# ['fetch', 'fetch']
# ['also', 'didnt']
# ['pdate', 'double', 'mins', 'txts', 'orange', 'tariffs', 'latest', 'motorola', 'sonyericsson', 'nokia', 'bluetooth', 'free', 'call', 'mobileupd', 'call', 'optout']
# ['someone', 'know', 'asked', 'dating', 'service', 'contact', 'cant', 'guess', 'call', 'revealed']
# ['missionary', 'hook', 'doggy', 'hook', 'standing']
# ['watching', 'funny', 'bluff', 'izzit', 'impossible']
# ['please', 'mummy', 'call', 'father']
# ['want', 'show', 'world', 'princess', 'europe']
# ['dear', 'shall', 'mail', 'tonite', 'busy', 'street', 'shall', 'update', 'tonite', 'things', 'looking', 'varunnathu', 'edukkukayee', 'raksha', 'ollu', 'good', 'real', 'sense']
# ['cool', 'last', 'little', 'getting', 'time', 'soon']
# ['uploaded', 'mine', 'facebook']
# ['convey', 'regards']
# ['sexy', 'buns', 'word', 'morning', 'think']
# ['cheers', 'yeah', 'goodnite', 'shame', 'neva', 'came', 'gailxx']
# ['mobile', 'months', 'entitled', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'call', 'mobile', 'update', 'free']
# ['good', 'morning', 'repair', 'shop', 'reason', 'hour']
# ['good', 'morning', 'suffering', 'fever', 'dysentry', 'able', 'come', 'office', 'today']
# ['sorry', 'call', 'later', 'meeting']
# ['length', 'shorter', 'fringe', 'going', 'liao', 'lazy', 'distract', 'also']
# ['love', 'daddy', 'make', 'scream', 'pleasure', 'going', 'slap', 'dick']
# ['lets', 'next', 'week', 'princess']
# ['aiyo', 'scared', 'become', 'better', 'lookin', 'oredi']
# ['santa', 'calling', 'would', 'little', 'ones', 'like', 'call', 'santa', 'xmas', 'call', 'book', 'time', 'calls', 'last', 'mins', 'santacalling']
# ['laid', 'airtel', 'line', 'rest']
# ['unfortunately', 'found', 'pick', 'sister', 'airport', 'evening', 'think', 'going']
# []
# ['hack', 'chat', 'backdoor', 'entry', 'chat', 'rooms', 'fraction', 'cost', 'reply', 'call', 'subscribe']
# ['santa', 'calling', 'would', 'little', 'ones', 'like', 'call', 'santa', 'xmas', 'call', 'book', 'time']
# ['come', 'home', 'nice', 'meet', 'chat']
# ['unlimited', 'texts', 'limited', 'minutes']
# ['notice', 'like', 'looking', 'shit', 'mirror', 'youre', 'turning', 'right', 'freak']
# ['actually', 'quite', 'fast', 'slow', 'haha']
# ['make', 'lasagna', 'vodka']
# ['cost']
# ['dear', 'voucher', 'holder', 'claim', 'weeks', 'offer', 'please', 'http', 'wtlp', 'text', 'apply']
# ['cancer', 'moms', 'making', 'deal', 'regular', 'checkup', 'smear']
# ['okay', 'like', 'wont', 'haha', 'terms', 'conditions']
# ['private', 'account', 'statement', 'shows', 'redeemed', 'points', 'call', 'identifier', 'code', 'expires']
# ['real', 'getting', 'need', 'tickets', 'jacket', 'done', 'already', 'used', 'multis']
# ['hope', 'alright', 'babe', 'worry', 'might', 'felt', 'desparate', 'learned', 'fake', 'waiting', 'come', 'back', 'love']
# ['poor', 'baby', 'hope', 'urfeeling', 'bettersn', 'probthat', 'overdose', 'work', 'careful', 'lots', 'lovejen']
# ['great', 'shoot', 'loads', 'ready']
# ['prasanth', 'ettans', 'mother', 'passed', 'away', 'last', 'night', 'pray', 'family']
# ['wasted', 'chiong', 'liao']
# ['realy', 'sorry', 'recognise', 'number', 'confused', 'please']
# ['love', 'come', 'took', 'long', 'leave', 'zaher', 'words', 'happy', 'left', 'miss']
# ['work', 'timing']
# ['princess', 'going', 'make', 'moan']
# ['number']
# ['think', 'could', 'stop', 'like', 'hour', 'roommate', 'looking', 'stock', 'trip']
# ['browsin', 'compulsory']
# ['tomorrow', 'going', 'theatre', 'come', 'wherever', 'call', 'tell', 'come', 'tomorrow']
# ['valentine', 'game', 'send', 'friends', 'answers', 'someone', 'really', 'loves', 'ques', 'colour', 'suits', 'best', 'rply']
# ['mokka', 'players']
# ['intrepid', 'great', 'time', 'soon']
# ['slowly', 'love', 'need', 'clean', 'heart', 'blood', 'send', 'special', 'people', 'miracle', 'tomorrow']
# ['message', 'truro', 'hospital', 'phone', 'phone', 'side']
# ['clothes', 'jewelry', 'trips']
# ['show', 'colours', 'euro', 'offer', 'england', 'flag', 'lions', 'tone', 'phone', 'click', 'following', 'service', 'message', 'info']
# ['watching', 'footie', 'worried', 'going', 'blow', 'phil', 'neville']
# ['still', 'looking', 'much', 'earn']
# ['well', 'right', 'gonna', 'check', 'today', 'steam', 'sales', 'text', 'want', 'come']
# ['hello', 'site', 'download', 'songs', 'urgent']
# ['little', 'weather', 'kind', 'coccooning', 'home']
# ['finished', 'class']
# ['trouble', 'classes', 'well', 'dodgey', 'expecting', 'mine', 'tomo', 'recovery', 'time', 'place']
# []
# ['lotta', 'childporn', 'cars']
# ['train', 'back', 'northampton', 'afraid', 'staying', 'skyving', 'today', 'around', 'wednesday', 'though', 'fancy', 'comedy', 'club', 'week']
# ['okay', 'soon', 'best']
# ['awarded', 'city', 'break', 'could', 'summer', 'shopping', 'spree', 'every', 'store', 'skilgme', 'tscs', 'winawk', 'perwksub']
# ['tomorrow', 'going', 'theatre', 'come', 'wherever', 'call', 'tell', 'come', 'tomorrow']
# ['good', 'evening']
# ['free', 'mobile', 'video', 'player', 'free', 'movie', 'collect', 'text', 'free', 'extra', 'films', 'ordered', 'apply']
# ['thats', 'cool']
# ['tell', 'happen', 'dont', 'behave', 'like', 'need']
# ['thread', 'wishlist', 'section', 'forums', 'post', 'nitro', 'requests', 'start', 'last', 'page', 'collect', 'bottom']
# ['wanna', 'watch', 'movie']
# ['worse', 'uses', 'half', 'stops', 'better', 'complete']
# ['ummmmmaah', 'many', 'many', 'happy', 'returns', 'dear', 'sweet', 'heart', 'happy', 'birthday', 'dear']
# ['sent', 'wife', 'text', 'tell', 'relax', 'wkend']
# ['urgent', 'attempt', 'contact', 'call', 'csbcm', 'callcost', 'ppmmobilesvary']
# ['alrite', 'hunny', 'nite', 'didnt', 'goin', 'town', 'instead', 'chillin', 'bedroom', 'love']
# ['video', 'tape', 'pple', 'type', 'message', 'free', 'help', 'watch', 'infernal', 'affairs', 'along', 'asking', 'shuhui']
# ['either', 'idea', 'know', 'anyplaces', 'something']
# ['training', 'tomorrow']
# ['lesson', 'thinkin', 'going', 'earlier', 'parkin', 'kent', 'vale']
# ['madam', 'regret', 'disturbance', 'might', 'receive', 'reference', 'check', 'premarica', 'kindly', 'informed', 'rgds', 'rakhesh', 'kerala']
# ['want', 'send', 'something', 'sell', 'fast', 'easy', 'money']
# ['wish', 'feel', 'alone']
# ['mail']
# ['today', 'workin', 'free', 'thgt', 'workin', 'fren', 'shop']
# ['ring', 'comes', 'guys', 'costumes', 'gift', 'future', 'yowifes', 'hint', 'hint']
# ['still', 'want', 'yogasana', 'cine', 'bathe', 'steam', 'bath']
# ['dear', 'voucher', 'holder', 'next', 'meal', 'following', 'link', 'enjoy', 'dining', 'experiencehttp', 'vouch', 'etlp', 'dining']
# ['whenevr', 'whenevr', 'gray', 'remembr', 'listn', 'watevr', 'wanna', 'walk', 'little', 'promise', 'bring', 'back', 'smile']
# ['ringtone', 'club', 'polys', 'direct', 'mobile', 'every', 'week']
# ['shit', 'really', 'shocking', 'scary', 'cant', 'imagine', 'second', 'night', 'think', 'somewhere', 'could', 'crash', 'night', 'save', 'taxi']
# ['wait', 'cornwall', 'hope', 'tonight', 'well', 'rock', 'night', 'shite', 'anyway', 'going', 'good', 'night', 'speak', 'soon']
# ['thanks', 'continued', 'support', 'question', 'week', 'enter', 'draw', 'cash', 'name', 'president']
# ['right', 'wasnt', 'phoned', 'someone', 'number', 'like']
# ['send', 'email', 'mind', 'times', 'night']
# ['change', 'plan', 'liao', 'back']
# ['sexychat', 'girls', 'waiting', 'text', 'text', 'great', 'night', 'chatting', 'send', 'stop', 'stop', 'service']
# ['honey', 'find', 'much', 'sell', 'predicte', 'nigeria', 'many', 'times', 'used', 'important', 'reply', 'monday']
# ['know', 'wait', 'check']
# ['early', 'still', 'project', 'meeting']
# []
# ['said', 'plus', 'minus', 'leave', 'line', 'paragraphs']
# ['registered', 'sinco', 'payee', 'icicibank', 'enter', 'confirm', 'beware', 'frauds', 'share', 'disclose', 'anyone']
# ['rose', 'blood', 'blood', 'heart', 'heart', 'send', 'friends', 'including', 'like', 'back', 'poor', 'relation', 'need', 'support', 'frnd', 'many', 'luvs', 'praying', 'marry']
# ['urgently', 'urgent', 'shortage', 'lacs', 'source', 'arng', 'lacs', 'thats', 'prob']
# ['need', 'lunch', 'maggi']
# ['lousy', 'already', 'come', 'back', 'half', 'dead']
# ['dang', 'mean', 'send']
# ['stalk', 'profiles']
# ['babe', 'back', 'come', 'back']
# ['congrats', 'mobile', 'videophones', 'call', 'videochat', 'mates', 'play', 'java', 'games', 'dload', 'polyh', 'music', 'noline', 'rentl']
# ['chennai']
# ['making', 'dinner']
# ['still', 'around', 'looking', 'pick', 'later']
# ['goodmorning', 'sleeping']
# ['time', 'going', 'hostel']
# ['gonnamissu', 'much', 'would', 'send', 'postcard', 'buttheres', 'aboutas', 'much', 'chance', 'merememberin', 'asthere', 'ofsi', 'breakin', 'contract', 'yaxx']
# ['hello', 'darling', 'today', 'would', 'love', 'chat', 'dont', 'tell', 'look', 'like', 'sexy']
# ['knock', 'knock', 'whose', 'enter', 'weekly', 'draw', 'gift', 'voucher', 'store', 'choice', 'tkls', 'stoptxtstop', 'week']
# ['cutest', 'girl', 'world']
# ['could', 'starve', 'lose', 'pound']
# ['sonathaya', 'soladha', 'boss']
# ['early', 'already']
# ['eyes', 'philosophy']
# ['newest', 'harry', 'potter', 'order', 'phoenix', 'book', 'reply', 'harry', 'answer', 'questions', 'chance', 'first', 'among', 'readers']
# []
# ['going', 'thru', 'different', 'feeling', 'wavering', 'decisions', 'coping', 'individual', 'time', 'heal', 'everything', 'believe']
# ['ummmmmaah', 'many', 'many', 'happy', 'returns', 'dear', 'sweet', 'heart', 'happy', 'birthday', 'dear']
# ['smsservices', 'yourinclusive', 'text', 'credits', 'goto', 'comuk', 'login', 'unsubscribe', 'stop', 'extra', 'charge', 'help', 'comuk']
# ['happen']
# ['excellent', 'thought', 'misundrstud', 'frnd', 'hate', 'truth', 'hate', 'urself']
# ['many', 'happy', 'returns', 'wish', 'happy', 'birthday']
# ['much', 'close', 'heart', 'away', 'shattered', 'stay']
# ['certainly', 'puts', 'things', 'perspective', 'something', 'like', 'happens']
# ['finished']
# ['first', 'time', 'everything']
# ['night', 'ended', 'another', 'morning', 'come', 'special', 'smile', 'like', 'sunny', 'rays', 'leaves', 'worries', 'blue', 'blue', 'mrng']
# ['know', 'serving', 'mean']
# ['tell', 'friend', 'come', 'round', 'like']
# []
# ['much', 'willing']
# ['coming', 'pick']
# ['private', 'account', 'statement', 'shows', 'unredeemed', 'bonus', 'points', 'claim', 'call', 'identifier', 'code', 'expires']
# ['left', 'vague', 'said', 'would', 'inform', 'person', 'accounting', 'delayed', 'rent', 'discuss', 'housing', 'agency', 'renting', 'another', 'place', 'checking', 'online', 'places', 'around']
# ['finished', 'work']
# ['shop', 'till', 'drop', 'either', 'cash', 'travel', 'voucher', 'call', 'fixedline', 'cost', 'mobile', 'vary']
# ['well', 'confuses', 'things']
# ['comin', 'nite', 'tell', 'every', 'sorry', 'hope', 'goodtime', 'rang', 'melnite', 'ifink', 'mite', 'sorted', 'explain', 'everythin']
# ['height', 'recycling', 'read', 'twice', 'people', 'spend', 'time', 'earning', 'money', 'money', 'spent', 'spending', 'time', 'good', 'morning', 'keep', 'smiling']
# ['lost', 'pound', 'help']
# ['bishan', 'nearer', 'need', 'early', 'gotta', 'park']
# []
# ['hella', 'money', 'want', 'grand', 'nature', 'adventure', 'galileo', 'little']
# ['means', 'fine']
# ['realise', 'busy', 'trying', 'bother', 'exams', 'outta', 'cars']
# ['going', 'wipro', 'interview', 'today']
# ['oops', 'somerset', 'back', 'tomo', 'soon']
# ['freezing', 'home', 'remember', 'kiss', 'morning', 'love', 'think', 'missing']
# ['sorry', 'call', 'later']
# ['movie']
# ['otherwise', 'part', 'time', 'tuition']
# ['might', 'salon', 'boring']
# ['always', 'putting', 'business', 'pictures', 'facebook', 'open', 'people', 'ever', 'would', 'think', 'picture', 'room', 'would', 'hurt', 'make', 'feel', 'violated']
# ['number', 'gonna', 'massive', 'pain', 'rather', 'involved', 'possible']
# ['misplaced', 'number', 'sending', 'texts', 'number', 'wondering', 'heard', 'year', 'best', 'mcat', 'number', 'atlanta', 'friends']
# ['registered', 'subscriber', 'draw', 'gift', 'voucher', 'entered', 'receipt', 'correct', 'next', 'olympics']
# ['headin', 'towards', 'busetop']
# ['mind', 'happened', 'dont', 'uncomfortable']
# ['time', 'thinkin', 'goin']
# ['problem', 'taxi', 'tomorrow', 'tuesday', 'tuesday', 'think', 'going', 'cinema']
# ['honestly', 'made', 'lovely', 'promptly', 'dropped', 'keys', 'burnt', 'fingers', 'getting']
# ['apps', 'class', 'varaya', 'elaya']
# ['meeting', 'call', 'later']
# ['babe', 'doin', 'nite', 'love', 'annie']
# ['aight', 'time', 'want', 'come']
# ['anything']
# ['aathi', 'dear']
# ['came', 'hostel', 'going', 'sleep', 'call', 'class', 'hrishi']
# ['decided', 'head']
# []
# ['doin', 'baby', 'girl', 'hope', 'okay', 'every', 'time', 'call', 'phone', 'miss', 'touch']
# ['tone', 'club', 'subs', 'expired', 'reply', 'monoc', 'monos', 'polyc', 'polys', 'weekly', 'week', 'stop', 'stop', 'free', 'stream']
# ['congratulations', 'awarded', 'either', 'supply', 'virgin', 'records', 'mystery', 'gift', 'guaranteed', 'call', 'smsco', 'approx', 'mins']
# ['story', 'last', 'week', 'wife', 'wish', 'parents', 'forgot', 'kids', 'went', 'work', 'even', 'colleagues', 'wish']
# ['said', 'gonna', 'snow', 'start', 'around', 'tonite', 'predicting', 'inch', 'accumulation']
# ['well', 'leave', 'class', 'babe', 'never', 'came', 'back', 'hope', 'nice', 'sleep', 'love']
# ['ryder', 'unsold', 'gibbs']
# ['tell']
# ['wewa', 'iriver']
# ['hello', 'love', 'goes', 'wish', 'well', 'fine', 'babe', 'hope', 'find', 'prospects', 'miss', 'boytoy', 'teasing', 'kiss']
# ['give', 'plus', 'said', 'grinule', 'greet', 'whenever', 'speak']
# ['neva', 'tell', 'home']
# ['pick', 'give', 'enough', 'time', 'park']
# ['friend', 'studying', 'warwick', 'planned', 'shopping', 'concert', 'canceled', 'havn', 'seen', 'ages', 'yeah', 'together', 'sometime']
# ['tried', 'contact', 'reply', 'offer', 'mins', 'textand', 'video', 'phone', 'call', 'reply', 'free', 'delivery', 'tomorrow']
# ['congrats', 'mobile', 'videophones', 'call', 'videochat', 'mates', 'play', 'java', 'games', 'dload', 'polyh', 'music', 'noline', 'rentl']
# ['loved', 'propsd', 'didnt', 'mind', 'lttrs', 'frnds', 'threw', 'decided', 'aproach', 'time', 'truck', 'speeding', 'towards', 'girl', 'like', 'hell', 'saved', 'asked', 'fast', 'replied', 'boost', 'secret', 'energy', 'instantly', 'girl', 'shouted', 'energy', 'lived', 'happily', 'gthr', 'drinking', 'boost', 'evrydy', 'moral', 'story', 'free', 'msgs']
# ['sorry', 'text', 'drive', 'coherently', 'twenty']
# ['dear', 'voucher', 'holder', 'claim', 'weeks', 'offer', 'please', 'http', 'expressoffer', 'apply', 'stop', 'texts', 'stop']
# ['call', 'chance']
# ['think', 'disturbing']
# ['cartons', 'pleased', 'shelves']
# ['make', 'girl', 'happy', 'difficult', 'make', 'girls', 'happy', 'need', 'friend', 'companion', 'lover', 'chef', 'good', 'listener', 'organizer', 'good', 'boyfriend', 'clean', 'sympathetic', 'athletic', 'warm', 'courageous', 'determined', 'true', 'dependable', 'intelligent', 'psychologist', 'pest', 'exterminator', 'psychiatrist', 'healer', 'stylist', 'driver', 'aaniye', 'pudunga', 'venaam']
# ['vijay', 'going', 'talk', 'jaya']
# ['music', 'gift', 'vouchers', 'every', 'week', 'starting', 'word', 'draw', 'tscs', 'idew', 'skillgame', 'winaweek', 'ppermesssubscription']
# ['customer', 'place', 'call']
# ['happy', 'birthday', 'dreams', 'come', 'true']
# ['going', 'lunch', 'family', 'orchard']
# ['thought']
# ['fact', 'leave', 'think', 'addie', 'goes', 'back', 'school', 'tues']
# ['brother', 'transfered']
# ['thinl', 'role', 'like', 'sachin', 'standing', 'others']
# ['filthy', 'stories', 'girls', 'waiting']
# ['reply', 'name', 'address', 'receive', 'post', 'weeks', 'completely', 'free', 'accommodation', 'various', 'global', 'locations']
